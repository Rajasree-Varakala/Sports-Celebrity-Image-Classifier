# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/test1.jpg')
img.shape
# Out:
# (1038, 1600, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1038, 1600)

# %%
gray
# Out:
# array([[43, 43, 43, ..., 51, 51, 51],
#        [43, 43, 43, ..., 51, 51, 51],
#        [43, 43, 43, ..., 51, 51, 51],
#        ...,
#        [19, 19, 19, ..., 23, 23, 23],
#        [19, 19, 19, ..., 23, 23, 23],
#        [19, 19, 19, ..., 23, 23, 23]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[660, 280, 685, 685]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (np.int32(660), np.int32(280), np.int32(685), np.int32(685))

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (685, 685, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/test2.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/test2.jpg')
if cropped_image is not None:
    plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
    plt.title('Cropped Image')
    plt.show()
else:
    print("No face with at least two eyes detected.")
# Out:
# No face with at least two eyes detected.

# %%
original_image = cv2.imread('./test_images/test3.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/test3.jpg')
if cropped_image is not None:
    plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
    plt.title('Cropped Image')
    plt.show()
else:
    print("No face with at least two eyes detected.")

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/kapil_dev',
#  './dataset/mary_kom',
#  './dataset/saina_nehwal',
#  './dataset/smriti_mandhana',
#  './dataset/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/kapil_dev
# Generating cropped images in folder:  ./dataset/cropped/mary_kom
# Generating cropped images in folder:  ./dataset/cropped/saina_nehwal
# Generating cropped images in folder:  ./dataset/cropped/smriti_mandhana
# Generating cropped images in folder:  ./dataset/cropped/virat_kohli

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'kapil_dev': ['./dataset/cropped/kapil_dev\\kapil_dev1.png',
#   './dataset/cropped/kapil_dev\\kapil_dev10.png',
#   './dataset/cropped/kapil_dev\\kapil_dev11.png',
#   './dataset/cropped/kapil_dev\\kapil_dev12.png',
#   './dataset/cropped/kapil_dev\\kapil_dev13.png',
#   './dataset/cropped/kapil_dev\\kapil_dev14.png',
#   './dataset/cropped/kapil_dev\\kapil_dev15.png',
#   './dataset/cropped/kapil_dev\\kapil_dev16.png',
#   './dataset/cropped/kapil_dev\\kapil_dev17.png',
#   './dataset/cropped/kapil_dev\\kapil_dev18.png',
#   './dataset/cropped/kapil_dev\\kapil_dev19.png',
#   './dataset/cropped/kapil_dev\\kapil_dev2.png',
#   './dataset/cropped/kapil_dev\\kapil_dev20.png',
#   './dataset/cropped/kapil_dev\\kapil_dev21.png',
#   './dataset/cropped/kapil_dev\\kapil_dev22.png',
#   './dataset/cropped/kapil_dev\\kapil_dev23.png',
#   './dataset/cropped/kapil_dev\\kapil_dev24.png',
#   './dataset/cropped/kapil_dev\\kapil_dev25.png',
#   './dataset/cropped/kapil_dev\\kapil_dev26.png',
#   './dataset/cropped/kapil_dev\\kapil_dev27.png',
#   './dataset/cropped/kapil_dev\\kapil_dev28.png',
#   './dataset/cropped/kapil_dev\\kapil_dev29.png',
#   './dataset/cropped/kapil_dev\\kapil_dev3.png',
#   './dataset/cropped/kapil_dev\\kapil_dev30.png',
#   './dataset/cropped/kapil_dev\\kapil_dev31.png',
#   './dataset/cropped/kapil_dev\\kapil_dev32.png',
#   './dataset/cropped/kapil_dev\\kapil_dev33.png',
#   './dataset/cropped/kapil_dev\\kapil_dev34.png',
#   './dataset/cropped/kapil_dev\\kapil_dev35.png',
#   './dataset/cropped/kapil_dev\\kapil_dev36.png',
#   './dataset/cropped/kapil_dev\\kapil_dev4.png',
#   './dataset/cropped/kapil_dev\\kapil_dev5.png',
#   './dataset/cropped/kapil_dev\\kapil_dev6.png',
#   './dataset/cropped/kapil_dev\\kapil_dev7.png',
#   './dataset/cropped/kapil_dev\\kapil_dev8.png',
#   './dataset/cropped/kapil_dev\\kapil_dev9.png'],
#  'mary_kom': ['./dataset/cropped/mary_kom\\mary_kom1.png',
#   './dataset/cropped/mary_kom\\mary_kom10.png',
#   './dataset/cropped/mary_kom\\mary_kom11.png',
#   './dataset/cropped/mary_kom\\mary_kom12.png',
#   './dataset/cropped/mary_kom\\mary_kom13.png',
#   './dataset/cropped/mary_kom\\mary_kom14.png',
#   './dataset/cropped/mary_kom\\mary_kom2.png',
#   './dataset/cropped/mary_kom\\mary_kom3.png',
#   './dataset/cropped/mary_kom\\mary_kom4.png',
#   './dataset/cropped/mary_kom\\mary_kom5.png',
#   './dataset/cropped/mary_kom\\mary_kom6.png',
#   './dataset/cropped/mary_kom\\mary_kom7.png',
#   './dataset/cropped/mary_kom\\mary_kom8.png',
#   './dataset/cropped/mary_kom\\mary_kom9.png'],
#  'saina_nehwal': ['./dataset/cropped/saina_nehwal\\saina_nehwal1.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal10.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal11.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal12.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal13.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal14.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal15.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal16.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal17.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal18.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal19.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal2.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal20.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal21.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal22.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal23.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal24.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal25.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal26.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal27.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal28.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal29.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal3.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal30.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal31.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal32.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal4.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal5.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal6.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal7.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal8.png',
#   './dataset/cropped/saina_nehwal\\saina_nehwal9.png'],
#  'smriti_mandhana': ['./dataset/cropped/smriti_mandhana\\smriti_mandhana1.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana10.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana11.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana12.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana13.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana14.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana15.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana16.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana17.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana18.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana19.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana2.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana20.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana21.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana22.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana23.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana24.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana25.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana26.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana27.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana28.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana29.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana3.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana4.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana5.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana6.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana7.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana8.png',
#   './dataset/cropped/smriti_mandhana\\smriti_mandhana9.png'],
#  'virat_kohli': ['./dataset/cropped/virat_kohli\\virat_kohli1.png',
#   './dataset/cropped/virat_kohli\\virat_kohli10.png',
#   './dataset/cropped/virat_kohli\\virat_kohli11.png',
#   './dataset/cropped/virat_kohli\\virat_kohli12.png',
#   './dataset/cropped/virat_kohli\\virat_kohli13.png',
#   './dataset/cropped/virat_kohli\\virat_kohli14.png',
#   './dataset/cropped/virat_kohli\\virat_kohli15.png',
#   './dataset/cropped/virat_kohli\\virat_kohli16.png',
#   './dataset/cropped/virat_kohli\\virat_kohli2.png',
#   './dataset/cropped/virat_kohli\\virat_kohli3.png',
#   './dataset/cropped/virat_kohli\\virat_kohli4.png',
#   './dataset/cropped/virat_kohli\\virat_kohli5.png',
#   './dataset/cropped/virat_kohli\\virat_kohli6.png',
#   './dataset/cropped/virat_kohli\\virat_kohli7.png',
#   './dataset/cropped/virat_kohli\\virat_kohli8.png',
#   './dataset/cropped/virat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'kapil_dev': 0,
#  'mary_kom': 1,
#  'saina_nehwal': 2,
#  'smriti_mandhana': 3,
#  'virat_kohli': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3+32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[114],
#        [ 92],
#        [117],
#        ...,
#        [210],
#        [232],
#        [ 91]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (127, 4096)

# %%
X[0]
# Out:
# array([114.,  92., 117., ..., 210., 232.,  91.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.84375

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        11
#            1       1.00      0.50      0.67         2
#            2       0.86      0.75      0.80         8
#            3       0.73      0.89      0.80         9
#            4       1.00      1.00      1.00         2
#
#     accuracy                           0.84        32
#    macro avg       0.90      0.81      0.84        32
# weighted avg       0.86      0.84      0.84        32

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\rajas\pywavelets-env\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.810526
# 1        random_forest    0.631579
# 2  logistic_regression    0.810526
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, multi_class='auto',
#                                      solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.90625

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6875

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.875

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[9, 0, 1, 1, 0],
#        [0, 2, 0, 0, 0],
#        [0, 1, 7, 0, 0],
#        [0, 0, 0, 9, 0],
#        [0, 0, 0, 0, 2]])

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'kapil_dev': 0,
#  'mary_kom': 1,
#  'saina_nehwal': 2,
#  'smriti_mandhana': 3,
#  'virat_kohli': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\rajas\anaconda3\envs\pywavelets-env-39\lib\site-packages (1.4.2)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
